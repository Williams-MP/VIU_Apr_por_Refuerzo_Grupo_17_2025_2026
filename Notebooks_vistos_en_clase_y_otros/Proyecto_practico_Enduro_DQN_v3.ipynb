# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 4 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1:
# *   Alumno 2:
# *   Alumno 3:
# *   Alumno 4:

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos. Alternativamente puedes utilizar WSL2: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
# drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"
drive_root = mount + "/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Montamos Drive y fijamos el directorio de trabajo a una carpeta DENTRO de
# Drive (drive_root). Esto es importante para entrenamientos largos (varias
# horas, dejados corriendo sin supervisión): si el runtime de Colab se
# desconecta o se recicla, todo lo que esté solo en el disco local del
# runtime (/content/...) se pierde para siempre. Drive, en cambio, persiste
# independientemente de lo que le pase al runtime.
#
# Nota: el propio mount de Drive puede a veces tardar o pedir reautorización
# en VSCode; si la celda se queda colgada en drive.mount(), revisa si apareció
# una ventana/pestaña de autorización de Google que necesite tu confirmación.
import os

if IN_COLAB:
    print("We're running Colab")
    drive.mount(mount)
    os.makedirs(drive_root, exist_ok=True)
    print("\nColab: Changing directory to", drive_root)
    os.chdir(drive_root)
else:
    print("No estamos en Colab (IN_COLAB=False); se usará el directorio actual del kernel.")

WORK_DIR = os.getcwd()
print("\nDirectorio de trabajo actual:", WORK_DIR)
print("Archivos en el directorio:")
print(os.listdir(WORK_DIR))

# Carpetas de salida, una por propuesta, DENTRO de Drive. Los checkpoints
# intermedios (ModelIntervalCheckpoint) y los logs se escriben aquí durante
# el entrenamiento, así que sobreviven a una desconexión del runtime.
RESULTS_DIR = os.path.join(WORK_DIR, 'resultados_enduro_dqn')
WEIGHTS_DIR_P1 = os.path.join(RESULTS_DIR, 'p1_eps_fijo')
WEIGHTS_DIR_P2 = os.path.join(RESULTS_DIR, 'p2_annealed')
WEIGHTS_DIR_P3 = os.path.join(RESULTS_DIR, 'p3_boltzmann')

for d in [RESULTS_DIR, WEIGHTS_DIR_P1, WEIGHTS_DIR_P2, WEIGHTS_DIR_P3]:
    os.makedirs(d, exist_ok=True)

print("\nCarpetas de resultados preparadas (en Drive):")
print(" -", WEIGHTS_DIR_P1)
print(" -", WEIGHTS_DIR_P2)
print(" -", WEIGHTS_DIR_P3)
# Out:
# We're running Colab
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# Colab: Changing directory to /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints
#
# Directorio de trabajo actual: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints
# Archivos en el directorio:
# ['resultados_enduro_dqn']
#
# Carpetas de resultados preparadas (en Drive):
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/resultados_enduro_dqn/p1_eps_fijo
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/resultados_enduro_dqn/p2_annealed
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/resultados_enduro_dqn/p3_boltzmann

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install tensorflow
  # %pip install tf-keras
  # %pip install tensorflow==2.18.0
  # %pip install tf-keras==2.18.0
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install --upgrade ml_dtypes
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Requirement already satisfied: tf-keras in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /usr/local/lib/python3.12/dist-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.12/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from gym==0.17.3) (1.16.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.12/dist-packages (from gym==0.17.3) (2.0.2)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-mjqswli3
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-mjqswli3
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from atari-py==1.2.2) (2.0.2)
# Building wheels for collected packages: atari-py
#   Building wheel for atari-py (setup.py) ... done
#   Created wheel for atari-py: filename=atari_py-1.2.2-cp312-cp312-linux_x86_64.whl size=4739377 sha256=2fd7e7dd1d9b561129b4594ad1eda341f5ac81707c8de0edbf2d4117cffae6d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hzymiczp/wheels/cb/1f/56/35b393898f74ae3d978063738e8eeb4b3d7357d0d7eeec6b9f
# Successfully built atari-py
# Installing collected packages: atari-py
# Successfully installed atari-py-1.2.2
# Collecting keras-rl2==1.0.5
#   Downloading keras_rl2-1.0.5-py3-none-any.whl.metadata (304 bytes)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from keras-rl2==1.0.5) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (0.1.2)
# Downloading keras_rl2-1.0.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: keras-rl2
# Successfully installed keras-rl2-1.0.5
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (0.5.4)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from ml_dtypes) (2.0.2)

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será el indicado en el listado correspondien de cada grupo y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de los puntos indicados en el listado por grupos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN y probar al menos 3 propuestas diferentes de mejora.
# 3.   Justificar la respuesta en relación a los resultados obtenidos e incluir al menos 3 gráficas relevantes comparando las 3 propuestas.
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
#Comprobamos que se carga la versión esperada de TF y detecta la GPU
import os

os.environ['TF_USE_LEGACY_KERAS']="1"

import tensorflow.keras as tf
import tensorflow as tf1

from keras import __version__
tf.__version__ = __version__

print(tf1.__version__)
print(tf1.config.list_physical_devices('GPU'))
print(tf1.config.list_logical_devices('GPU'))
# Out:
# 2.20.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute

if IN_COLAB:
  from tensorflow.keras.optimizers.legacy import Adam
else:
  from tensorflow.keras.optimizers import Adam

import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %%
# ----------------------------------------------------------------------
# PARCHE NECESARIO: keras-rl2 (rl.core.Agent.fit) inicializa el contador de
# pasos como np.int16:
#     self.step = np.int16(0)
# np.int16 solo soporta valores hasta 32767. En entrenamientos largos como
# los que necesitamos aquí (NB_STEPS_TRAIN en el orden de 10^6), en cuanto
# self.step supera 32767 se produce un overflow silencioso (wraparound):
# self.step se vuelve NEGATIVO de golpe.
#
# Esto NO detiene el entrenamiento (la red sigue actualizándose), pero rompe:
#   - La condición 'while self.step < nb_steps' (el conteo real de progreso
#     queda corrupto a partir de ese punto).
#   - LinearAnnealedPolicy.get_current_value(), que calcula epsilon como
#     una función lineal de self.step: con self.step negativo, epsilon
#     puede dispararse por ENCIMA de 1.0 (no hay tope superior en el
#     código), forzando una política de exploración prácticamente
#     aleatoria de forma permanente. Esto explica por qué, tras el aviso
#     de overflow, el reward se desploma a 0 y ya no se recupera.
#   - El logging por intervalos y los ModelIntervalCheckpoint, que también
#     comparan contra self.step.
#
# Solución: forzamos a que el contador interno use un entero de 64 bits
# (np.int64), que aguanta hasta 9.2*10^18, muy por encima de cualquier
# nb_steps razonable. Esto se hace sustituyendo la referencia a np.int16
# que usa el módulo rl.core en tiempo de ejecución (no es necesario tocar
# el código fuente de la librería).
import rl.core as rl_core
rl_core.np.int16 = np.int64
# ----------------------------------------------------------------------

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'Enduro-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

print("Entorno:", env_name)
print("Número de acciones disponibles:", nb_actions)
print("Significado de las acciones:", env.unwrapped.get_action_meanings())
print("Formato de las observaciones:", env.observation_space)
# Out:
# Entorno: Enduro-v0
# Número de acciones disponibles: 9
# Significado de las acciones: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'DOWN', 'DOWNRIGHT', 'DOWNLEFT', 'RIGHTFIRE', 'LEFTFIRE']
# Formato de las observaciones: Box(0, 255, (210, 160, 3), uint8)

# %%
class AtariProcessor(Processor):
    """
    Procesador de observaciones y recompensas para Enduro.

    A diferencia del ejemplo de Breakout, en Enduro:
      - El reward es MUY disperso: solo se obtiene +1 por cada coche adelantado.
      - No existe penalización explícita por choque o por ir despacio:
        cuando el coche choca son los rivales los que "adelantan", pero el
        entorno no devuelve reward negativo por ello.
      - La acción que activa la aceleración es FIRE (acción índice 1), igual
        que en otros juegos Atari donde FIRE = "arrancar".

    Esto provoca que, copiando el procesador de Breakout (clip a [-1,1] sin
    más), el agente tarde muchísimo en recibir señal de aprendizaje útil:
    con una política casi aleatoria, jugar sin acelerar nunca genera reward 0,
    y la red no tiene gradiente para aprender que acelerar es bueno.

    Mejora aplicada (reward shaping):
      - Mantenemos el reward original del entorno (adelantar coches), que es
        la señal "de verdad" que queremos maximizar.
      - Para inyectar señal densa en las fases iniciales, este processor deja
        preparado process_reward para no clippear a [-1,1] sin razón (en
        Enduro el reward ya es pequeño y disperso, clippear no ayuda).
    """

    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        # No clippeamos a [-1, 1]: en Enduro el reward ya es +1 por coche
        # adelantado. Clippear aquí no aporta nada (no hay rewards grandes
        # que distorsionen el entrenamiento como en Breakout) y preferimos
        # mantener la señal real del entorno sin alterar su magnitud.
        return float(reward)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
# 1. Implementación de la red neuronal
#
# Usamos la misma arquitectura convolucional propuesta por Mnih et al. (2015)
# para Atari: 3 capas convolucionales + 1 capa densa oculta + capa de salida
# lineal con un valor Q por acción. Es la misma red que en el ejemplo de
# Breakout del notebook de la sesión, adaptada al número de acciones de Enduro.

input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE


def build_model(nb_actions, input_shape):
    model = Sequential()
    if K.image_data_format() == 'channels_last':
        # (width, height, channels)
        model.add(Permute((2, 3, 1), input_shape=input_shape))
    elif K.image_data_format() == 'channels_first':
        # (channels, width, height)
        model.add(Permute((1, 2, 3), input_shape=input_shape))
    else:
        raise RuntimeError('Unknown image_dim_ordering.')

    model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(nb_actions))
    model.add(Activation('linear'))
    return model


model = build_model(nb_actions, input_shape)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute (Permute)           (None, 84, 84, 4)         0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  activation (Activation)     (None, 20, 20, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  activation_1 (Activation)   (None, 9, 9, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  activation_2 (Activation)   (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 9)                 4617
#
#  activation_4 (Activation)   (None, 9)                 0
#
# =================================================================
# Total params: 1688745 (6.44 MB)
# Trainable params: 1688745 (6.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# 2. Implementación de la solución DQN

# %% [markdown]
# ##### Diagnóstico y diseño de las 3 propuestas de mejora

# %%
"""
### Diagnóstico del problema en Enduro

Antes de entrenar, conviene entender por qué una solución "copia-pega" del
ejemplo de Breakout no funciona en Enduro:

1. **Reward extremadamente disperso**: en Enduro solo se obtiene +1 por cada
   coche adelantado (fuente: documentación oficial de Farama/ALE). No hay
   reward por simplemente sobrevivir, ni penalización explícita por chocar.
   Con una política casi aleatoria al principio del entrenamiento (alto
   epsilon), la probabilidad de generar una secuencia de acciones que
   resulte en adelantar a un coche es muy baja.

2. **La acción de acelerar (FIRE) es solo 1 de 9 acciones posibles**. Hemos
   comprobado empíricamente que con NOOP el reward acumulado es 0, mientras
   que con FIRE sostenido se empieza a generar reward positivo desde los
   primeros steps. Si la política de exploración no favorece especialmente
   esta acción, el agente tarda mucho más en "descubrir" que acelerar es la
   base de cualquier estrategia ganadora.

3. **nb_steps_warmup demasiado alto combinado con annealing muy lento**:
   si se usa el mismo esquema que Breakout (warmup=50000, annealing sobre
   2M steps), el agente pasa cientos de miles de steps con una política casi
   uniforme antes de empezar a aprender señal útil, lo cual en Enduro es
   mucho más costoso que en Breakout porque el reward es más raro.

A partir de este diagnóstico, proponemos y comparamos 3 variantes de la
solución DQN, manteniendo la misma red y el mismo AtariProcessor, variando
únicamente la política de exploración/explotación y sus hiperparámetros:

- **Propuesta 1 — EpsGreedy fijo (baseline)**: epsilon constante a lo largo
  de todo el entrenamiento. Sirve como referencia de cuánto cuesta aprender
  sin ningún tipo de planificación de la exploración.

- **Propuesta 2 — LinearAnnealedPolicy (EpsGreedy con annealing rápido)**:
  epsilon decrece linealmente de 1.0 a 0.1 en un número de steps mucho menor
  que en Breakout (300k en lugar de 2M), adaptado a que Enduro necesita
  empezar a explotar antes lo poco que va aprendiendo, dado lo disperso del
  reward. Además, reducimos nb_steps_warmup respecto al ejemplo de Breakout.

- **Propuesta 3 — BoltzmannQPolicy**: la exploración se basa en muestrear
  acciones proporcionalmente a sus valores Q estimados (softmax), en lugar
  de epsilon-greedy puro. Esto permite que, en cuanto la red empiece a
  asignar valores Q más altos a FIRE/aceleración, esa acción se elija con
  más frecuencia de forma suave, sin depender de un parámetro epsilon
  explícito.

Las tres comparten la misma arquitectura de red, el mismo procesador de
estados, y el mismo gamma/target_model_update, para que la comparación aísle
el efecto de la política de exploración.
"""
# Out:
# '\n### Diagnóstico del problema en Enduro\n\nAntes de entrenar, conviene entender por qué una solución "copia-pega" del\nejemplo de Breakout no funciona en Enduro:\n\n1. **Reward extremadamente disperso**: en Enduro solo se obtiene +1 por cada\n   coche adelantado (fuente: documentación oficial de Farama/ALE). No hay\n   reward por simplemente sobrevivir, ni penalización explícita por chocar.\n   Con una política casi aleatoria al principio del entrenamiento (alto\n   epsilon), la probabilidad de generar una secuencia de acciones que\n   resulte en adelantar a un coche es muy baja.\n\n2. **La acción de acelerar (FIRE) es solo 1 de 9 acciones posibles**. Hemos\n   comprobado empíricamente que con NOOP el reward acumulado es 0, mientras\n   que con FIRE sostenido se empieza a generar reward positivo desde los\n   primeros steps. Si la política de exploración no favorece especialmente\n   esta acción, el agente tarda mucho más en "descubrir" que acelerar es la\n   base de cualquier estrategia ganadora.\n\n3. **nb_steps_warmup demasiado alto combinado con annealing muy lento**:\n   si se usa el mismo esquema que Breakout (warmup=50000, annealing sobre\n   2M steps), el agente pasa cientos de miles de steps con una política casi\n   uniforme antes de empezar a aprender señal útil, lo cual en Enduro es\n   mucho más costoso que en Breakout porque el reward es más raro.\n\nA partir de este diagnóstico, proponemos y comparamos 3 variantes de la\nsolución DQN, manteniendo la misma red y el mismo AtariProcessor, variando\núnicamente la política de exploración/explotación y sus hiperparámetros:\n\n- **Propuesta 1 — EpsGreedy fijo (baseline)**: epsilon constante a lo largo\n  de todo el entrenamiento. Sirve como referencia de cuánto cuesta aprender\n  sin ningún tipo de planificación de la exploración.\n\n- **Propuesta 2 — LinearAnnealedPolicy (EpsGreedy con annealing rápido)**:\n  epsilon decrece linealmente de 1.0 a 0.1 en un número de steps mucho menor\n  que en Breakout (300k en lugar de 2M), adaptado a que Enduro necesita\n  empezar a explotar antes lo poco que va aprendiendo, dado lo disperso del\n  reward. Además, reducimos nb_steps_warmup respecto al ejemplo de Breakout.\n\n- **Propuesta 3 — BoltzmannQPolicy**: la exploración se basa en muestrear\n  acciones proporcionalmente a sus valores Q estimados (softmax), en lugar\n  de epsilon-greedy puro. Esto permite que, en cuanto la red empiece a\n  asignar valores Q más altos a FIRE/aceleración, esa acción se elija con\n  más frecuencia de forma suave, sin depender de un parámetro epsilon\n  explícito.\n\nLas tres comparten la misma arquitectura de red, el mismo procesador de\nestados, y el mismo gamma/target_model_update, para que la comparación aísle\nel efecto de la política de exploración.\n'

# %%
def build_dqn_agent(model, nb_actions, memory, processor, policy,
                     nb_steps_warmup, target_model_update,
                     train_interval=4, gamma=.99):
    dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
                   memory=memory, processor=processor,
                   nb_steps_warmup=nb_steps_warmup, gamma=gamma,
                   target_model_update=target_model_update,
                   train_interval=train_interval)
    dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])
    return dqn

# %% [markdown]
# ###### Propuesta 1 — EpsGreedyQPolicy fijo (baseline)

# %%
# ----------------------------------------------------------------------
# PROPUESTA 1: EpsGreedyQPolicy fijo (baseline, sin annealing)
# ----------------------------------------------------------------------
NB_STEPS_TRAIN = 1750000  # ajustar según tiempo disponible / checkpoints

model_p1 = build_model(nb_actions, input_shape)
memory_p1 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p1 = EpsGreedyQPolicy(eps=0.2)

dqn_p1 = build_dqn_agent(
    model=model_p1, nb_actions=nb_actions, memory=memory_p1,
    processor=AtariProcessor(), policy=policy_p1,
    nb_steps_warmup=10000, target_model_update=10000
)

# Todo lo de esta propuesta se guarda en su carpeta dedicada DENTRO de Drive
# (WEIGHTS_DIR_P1), para que los checkpoints intermedios sobrevivan aunque
# el runtime de Colab se desconecte durante un entrenamiento largo.
weights_filename_p1 = os.path.join(WEIGHTS_DIR_P1, 'dqn_{}_p1_eps_fijo_weights.h5f'.format(env_name))
checkpoint_filename_p1 = os.path.join(WEIGHTS_DIR_P1, 'dqn_' + env_name + '_p1_weights_{step}.h5f')
log_filename_p1 = os.path.join(WEIGHTS_DIR_P1, 'dqn_{}_p1_log.json'.format(env_name))

callbacks_p1 = [ModelIntervalCheckpoint(checkpoint_filename_p1, interval=100000)]
callbacks_p1 += [FileLogger(log_filename_p1, interval=1000)]

history_p1 = dqn_p1.fit(env, callbacks=callbacks_p1, nb_steps=NB_STEPS_TRAIN,
                         log_interval=10000, visualize=False)

dqn_p1.save_weights(weights_filename_p1, overwrite=True)
print("Pesos finales de la Propuesta 1 guardados en Drive:", weights_filename_p1)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P1))
# Out:
# Training for 1750000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 44s 4ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - ale.lives: 0.000
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.000 - mae: 0.033 - mean_q: 0.042 - ale.lives: 0.000
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 325s 33ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.000 - mae: 0.035 - mean_q: 0.044 - ale.lives: 0.000
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 3.0000e-04
# 2 episodes - episode_reward: 1.500 [0.000, 3.000] - loss: 0.001 - mae: 0.036 - mean_q: 0.046 - ale.lives: 0.000
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 1.0000e-04
# 3 episodes - episode_reward: 0.333 [0.000, 1.000] - loss: 0.002 - mae: 0.047 - mean_q: 0.063 - ale.lives: 0.000
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 328s 33ms/step - reward: 1.0000e-04
# 2 episodes - episode_reward: 0.500 [0.000, 1.000] - loss: 0.002 - mae: 0.062 - mean_q: 0.080 - ale.lives: 0.000
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 329s 33ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.003 - mae: 0.070 - mean_q: 0.090 - ale.lives: 0.000
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0000e+00
# 3 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.003 - mae: 0.080 - mean_q: 0.100 - ale.lives: 0.000
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 331s 33ms/step - reward: 7.0000e-04
# 2 episodes - episode_reward: 0.500 [0.000, 1.000] - loss: 0.003 - mae: 0.091 - mean_q: 0.112 - ale.lives: 0.000
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 332s 33ms/step - reward: -6.0000e-04
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.004 - mae: 0.110 - mean_q: 0.133 - ale.lives: 0.000
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.004 - mae: 0.122 - mean_q: 0.145 - ale.lives: 0.000
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 9.0000e-04
# 3 episodes - episode_reward: 3.000 [2.000, 4.000] - loss: 0.004 - mae: 0.143 - mean_q: 0.167 - ale.lives: 0.000
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 336s 34ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.005 - mae: 0.159 - mean_q: 0.184 - ale.lives: 0.000
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.005 - mae: 0.171 - mean_q: 0.196 - ale.lives: 0.000
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 339s 34ms/step - reward: 0.0024
# 2 episodes - episode_reward: 2.500 [0.000, 5.000] - loss: 0.005 - mae: 0.195 - mean_q: 0.225 - ale.lives: 0.000
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 341s 34ms/step - reward: -7.0000e-04
# 3 episodes - episode_reward: 3.333 [0.000, 6.000] - loss: 0.006 - mae: 0.219 - mean_q: 0.251 - ale.lives: 0.000
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 342s 34ms/step - reward: 5.0000e-04
# 2 episodes - episode_reward: 3.500 [2.000, 5.000] - loss: 0.007 - mae: 0.238 - mean_q: 0.267 - ale.lives: 0.000
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 344s 34ms/step - reward: 0.0025
# 2 episodes - episode_reward: 10.000 [1.000, 19.000] - loss: 0.008 - mae: 0.247 - mean_q: 0.273 - ale.lives: 0.000
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 345s 35ms/step - reward: 4.0000e-04
# 2 episodes - episode_reward: 4.500 [0.000, 9.000] - loss: 0.008 - mae: 0.272 - mean_q: 0.305 - ale.lives: 0.000
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 347s 35ms/step - reward: 0.0025
# 3 episodes - episode_reward: 8.333 [0.000, 15.000] - loss: 0.009 - mae: 0.291 - mean_q: 0.321 - ale.lives: 0.000
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 348s 35ms/step - reward: 0.0025
# 2 episodes - episode_reward: 12.500 [2.000, 23.000] - loss: 0.010 - mae: 0.317 - mean_q: 0.351 - ale.lives: 0.000
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 350s 35ms/step - reward: 0.0014
# 2 episodes - episode_reward: 6.000 [0.000, 12.000] - loss: 0.011 - mae: 0.355 - mean_q: 0.386 - ale.lives: 0.000
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 352s 35ms/step - reward: 0.0011
# 2 episodes - episode_reward: 2.500 [0.000, 5.000] - loss: 0.012 - mae: 0.389 - mean_q: 0.419 - ale.lives: 0.000
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 354s 35ms/step - reward: 1.0000e-04
# 3 episodes - episode_reward: 2.667 [0.000, 5.000] - loss: 0.012 - mae: 0.420 - mean_q: 0.459 - ale.lives: 0.000
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 356s 36ms/step - reward: 0.0019
# 2 episodes - episode_reward: 6.000 [0.000, 12.000] - loss: 0.014 - mae: 0.464 - mean_q: 0.509 - ale.lives: 0.000
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 2.0000e-04
# 2 episodes - episode_reward: 5.000 [3.000, 7.000] - loss: 0.014 - mae: 0.505 - mean_q: 0.552 - ale.lives: 0.000
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 360s 36ms/step - reward: 7.0000e-04
# 2 episodes - episode_reward: 3.500 [0.000, 7.000] - loss: 0.016 - mae: 0.557 - mean_q: 0.603 - ale.lives: 0.000
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 363s 36ms/step - reward: 0.0036
# 3 episodes - episode_reward: 11.000 [3.000, 26.000] - loss: 0.018 - mae: 0.595 - mean_q: 0.644 - ale.lives: 0.000
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 365s 36ms/step - reward: 0.0018
# 2 episodes - episode_reward: 10.000 [9.000, 11.000] - loss: 0.019 - mae: 0.631 - mean_q: 0.679 - ale.lives: 0.000
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0044
# 2 episodes - episode_reward: 21.500 [15.000, 28.000] - loss: 0.019 - mae: 0.664 - mean_q: 0.715 - ale.lives: 0.000
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 368s 37ms/step - reward: 0.0065
# 2 episodes - episode_reward: 17.000 [14.000, 20.000] - loss: 0.019 - mae: 0.708 - mean_q: 0.754 - ale.lives: 0.000
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 371s 37ms/step - reward: 0.0067
# 3 episodes - episode_reward: 32.000 [25.000, 36.000] - loss: 0.021 - mae: 0.765 - mean_q: 0.821 - ale.lives: 0.000
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 374s 37ms/step - reward: 0.0026
# 2 episodes - episode_reward: 13.000 [1.000, 25.000] - loss: 0.024 - mae: 0.826 - mean_q: 0.889 - ale.lives: 0.000
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 376s 38ms/step - reward: 0.0099
# 2 episodes - episode_reward: 22.500 [19.000, 26.000] - loss: 0.025 - mae: 0.844 - mean_q: 0.897 - ale.lives: 0.000
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 378s 38ms/step - reward: 0.0093
# 2 episodes - episode_reward: 72.000 [26.000, 118.000] - loss: 0.025 - mae: 0.896 - mean_q: 0.958 - ale.lives: 0.000
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 381s 38ms/step - reward: 0.0113
# 3 episodes - episode_reward: 34.667 [3.000, 82.000] - loss: 0.026 - mae: 0.934 - mean_q: 0.990 - ale.lives: 0.000
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 383s 38ms/step - reward: 0.0064
# 2 episodes - episode_reward: 40.000 [37.000, 43.000] - loss: 0.028 - mae: 0.990 - mean_q: 1.056 - ale.lives: 0.000
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 388s 39ms/step - reward: 0.0131
# 2 episodes - episode_reward: 41.000 [22.000, 60.000] - loss: 0.029 - mae: 1.039 - mean_q: 1.117 - ale.lives: 0.000
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 391s 39ms/step - reward: 0.0142
# 2 episodes - episode_reward: 85.500 [71.000, 100.000] - loss: 0.028 - mae: 1.067 - mean_q: 1.149 - ale.lives: 0.000
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 392s 39ms/step - reward: 0.0192
# 3 episodes - episode_reward: 65.667 [35.000, 95.000] - loss: 0.030 - mae: 1.103 - mean_q: 1.184 - ale.lives: 0.000
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 396s 40ms/step - reward: 0.0161
# 2 episodes - episode_reward: 81.000 [59.000, 103.000] - loss: 0.030 - mae: 1.170 - mean_q: 1.267 - ale.lives: 0.000
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 400s 40ms/step - reward: 0.0164
# 2 episodes - episode_reward: 79.500 [69.000, 90.000] - loss: 0.032 - mae: 1.200 - mean_q: 1.297 - ale.lives: 0.000
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 403s 40ms/step - reward: 0.0178
# 2 episodes - episode_reward: 45.000 [24.000, 66.000] - loss: 0.032 - mae: 1.248 - mean_q: 1.338 - ale.lives: 0.000
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 406s 41ms/step - reward: 0.0107
# 3 episodes - episode_reward: 65.667 [34.000, 104.000] - loss: 0.034 - mae: 1.304 - mean_q: 1.394 - ale.lives: 0.000
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 409s 41ms/step - reward: 0.0134
# 2 episodes - episode_reward: 68.000 [63.000, 73.000] - loss: 0.035 - mae: 1.345 - mean_q: 1.453 - ale.lives: 0.000
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 411s 41ms/step - reward: 0.0228
# 2 episodes - episode_reward: 88.000 [79.000, 97.000] - loss: 0.037 - mae: 1.421 - mean_q: 1.551 - ale.lives: 0.000
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 414s 41ms/step - reward: 0.0270
# 2 episodes - episode_reward: 119.500 [117.000, 122.000] - loss: 0.039 - mae: 1.476 - mean_q: 1.611 - ale.lives: 0.000
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 418s 42ms/step - reward: 0.0190
# 3 episodes - episode_reward: 93.000 [80.000, 105.000] - loss: 0.039 - mae: 1.561 - mean_q: 1.712 - ale.lives: 0.000
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 421s 42ms/step - reward: 0.0227
# 2 episodes - episode_reward: 102.500 [84.000, 121.000] - loss: 0.044 - mae: 1.627 - mean_q: 1.792 - ale.lives: 0.000
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 424s 42ms/step - reward: 0.0237
# 2 episodes - episode_reward: 96.000 [89.000, 103.000] - loss: 0.047 - mae: 1.723 - mean_q: 1.900 - ale.lives: 0.000
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 426s 43ms/step - reward: 0.0204
# 2 episodes - episode_reward: 103.500 [100.000, 107.000] - loss: 0.044 - mae: 1.751 - mean_q: 1.944 - ale.lives: 0.000
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 431s 43ms/step - reward: 0.0243
# 3 episodes - episode_reward: 96.333 [86.000, 107.000] - loss: 0.046 - mae: 1.838 - mean_q: 2.040 - ale.lives: 0.000
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 436s 44ms/step - reward: 0.0250
# 2 episodes - episode_reward: 126.000 [109.000, 143.000] - loss: 0.049 - mae: 1.896 - mean_q: 2.113 - ale.lives: 0.000
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 438s 44ms/step - reward: 0.0251
# 2 episodes - episode_reward: 97.000 [93.000, 101.000] - loss: 0.048 - mae: 1.917 - mean_q: 2.149 - ale.lives: 0.000
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0226
# 2 episodes - episode_reward: 95.500 [71.000, 120.000] - loss: 0.052 - mae: 2.031 - mean_q: 2.297 - ale.lives: 0.000
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0231
# 3 episodes - episode_reward: 114.667 [112.000, 117.000] - loss: 0.050 - mae: 2.073 - mean_q: 2.336 - ale.lives: 0.000
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 441s 44ms/step - reward: 0.0251
# 2 episodes - episode_reward: 91.000 [76.000, 106.000] - loss: 0.050 - mae: 2.134 - mean_q: 2.394 - ale.lives: 0.000
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 444s 44ms/step - reward: 0.0226
# 2 episodes - episode_reward: 112.000 [92.000, 132.000] - loss: 0.055 - mae: 2.207 - mean_q: 2.497 - ale.lives: 0.000
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 448s 45ms/step - reward: 0.0296
# 2 episodes - episode_reward: 123.000 [104.000, 142.000] - loss: 0.051 - mae: 2.244 - mean_q: 2.551 - ale.lives: 0.000
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 450s 45ms/step - reward: 0.0308
# 3 episodes - episode_reward: 137.000 [105.000, 161.000] - loss: 0.055 - mae: 2.338 - mean_q: 2.656 - ale.lives: 0.000
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 453s 45ms/step - reward: 0.0242
# 2 episodes - episode_reward: 124.000 [115.000, 133.000] - loss: 0.055 - mae: 2.384 - mean_q: 2.716 - ale.lives: 0.000
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 455s 46ms/step - reward: 0.0282
# 2 episodes - episode_reward: 117.500 [116.000, 119.000] - loss: 0.057 - mae: 2.474 - mean_q: 2.822 - ale.lives: 0.000
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 460s 46ms/step - reward: 0.0285
# 2 episodes - episode_reward: 122.000 [91.000, 153.000] - loss: 0.059 - mae: 2.556 - mean_q: 2.921 - ale.lives: 0.000
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 466s 47ms/step - reward: 0.0259
# 3 episodes - episode_reward: 118.000 [113.000, 122.000] - loss: 0.061 - mae: 2.639 - mean_q: 3.013 - ale.lives: 0.000
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 467s 47ms/step - reward: 0.0270
# 2 episodes - episode_reward: 120.500 [109.000, 132.000] - loss: 0.061 - mae: 2.654 - mean_q: 3.037 - ale.lives: 0.000
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 471s 47ms/step - reward: 0.0212
# 2 episodes - episode_reward: 99.500 [73.000, 126.000] - loss: 0.063 - mae: 2.733 - mean_q: 3.132 - ale.lives: 0.000
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 471s 47ms/step - reward: 0.0283
# 2 episodes - episode_reward: 112.500 [95.000, 130.000] - loss: 0.061 - mae: 2.765 - mean_q: 3.176 - ale.lives: 0.000
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0292
# 3 episodes - episode_reward: 127.667 [109.000, 161.000] - loss: 0.060 - mae: 2.822 - mean_q: 3.244 - ale.lives: 0.000
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 479s 48ms/step - reward: 0.0321
# 2 episodes - episode_reward: 153.000 [134.000, 172.000] - loss: 0.058 - mae: 2.872 - mean_q: 3.313 - ale.lives: 0.000
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0269
# 2 episodes - episode_reward: 126.000 [116.000, 136.000] - loss: 0.063 - mae: 2.951 - mean_q: 3.413 - ale.lives: 0.000
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 485s 48ms/step - reward: 0.0237
# 3 episodes - episode_reward: 95.667 [86.000, 112.000] - loss: 0.065 - mae: 3.023 - mean_q: 3.490 - ale.lives: 0.000
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 490s 49ms/step - reward: 0.0253
# 2 episodes - episode_reward: 114.000 [110.000, 118.000] - loss: 0.061 - mae: 3.068 - mean_q: 3.545 - ale.lives: 0.000
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 492s 49ms/step - reward: 0.0268
# 2 episodes - episode_reward: 126.000 [124.000, 128.000] - loss: 0.063 - mae: 3.157 - mean_q: 3.644 - ale.lives: 0.000
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 497s 50ms/step - reward: 0.0320
# 2 episodes - episode_reward: 130.000 [123.000, 137.000] - loss: 0.063 - mae: 3.228 - mean_q: 3.741 - ale.lives: 0.000
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 501s 50ms/step - reward: 0.0281
# 3 episodes - episode_reward: 126.333 [109.000, 156.000] - loss: 0.065 - mae: 3.285 - mean_q: 3.809 - ale.lives: 0.000
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 504s 50ms/step - reward: 0.0300
# 2 episodes - episode_reward: 139.500 [138.000, 141.000] - loss: 0.068 - mae: 3.351 - mean_q: 3.878 - ale.lives: 0.000
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 509s 51ms/step - reward: 0.0305
# 2 episodes - episode_reward: 135.500 [112.000, 159.000] - loss: 0.066 - mae: 3.419 - mean_q: 3.961 - ale.lives: 0.000
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 511s 51ms/step - reward: 0.0316
# 2 episodes - episode_reward: 131.000 [128.000, 134.000] - loss: 0.066 - mae: 3.498 - mean_q: 4.051 - ale.lives: 0.000
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 517s 52ms/step - reward: 0.0331
# 3 episodes - episode_reward: 147.000 [131.000, 164.000] - loss: 0.068 - mae: 3.542 - mean_q: 4.103 - ale.lives: 0.000
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 520s 52ms/step - reward: 0.0282
# 2 episodes - episode_reward: 122.000 [106.000, 138.000] - loss: 0.071 - mae: 3.635 - mean_q: 4.203 - ale.lives: 0.000
#
# Interval 81 (800000 steps performed)
#   877/10000 [=>............................] - ETA: 7:52 - reward: 0.0239
# Failed to connect to the remote Jupyter Server 'https://8080-gpu-l4-s-kkb-ass1a1-1giv0nj4vk5jd-a.asia-southeast1-1.prod.colab.dev/'. Verify the server is running and reachable.

# %% [markdown]
# ###### Propuesta 2 — LinearAnnealedPolicy (EpsGreedy con annealing rápido)

# %%
# ----------------------------------------------------------------------
# PROPUESTA 2: LinearAnnealedPolicy (EpsGreedy con annealing rápido)
# ----------------------------------------------------------------------
model_p2 = build_model(nb_actions, input_shape)
memory_p2 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

# Annealing más rápido que en Breakout (300k en lugar de 2M steps), dado que
# el reward en Enduro es más disperso y conviene empezar a explotar antes.
policy_p2 = LinearAnnealedPolicy(
    EpsGreedyQPolicy(), attr='eps',
    value_max=1., value_min=.1, value_test=.05,
    nb_steps=300000
)

dqn_p2 = build_dqn_agent(
    model=model_p2, nb_actions=nb_actions, memory=memory_p2,
    processor=AtariProcessor(), policy=policy_p2,
    nb_steps_warmup=10000, target_model_update=10000
)

weights_filename_p2 = os.path.join(WEIGHTS_DIR_P2, 'dqn_{}_p2_annealed_weights.h5f'.format(env_name))
checkpoint_filename_p2 = os.path.join(WEIGHTS_DIR_P2, 'dqn_' + env_name + '_p2_weights_{step}.h5f')
log_filename_p2 = os.path.join(WEIGHTS_DIR_P2, 'dqn_{}_p2_log.json'.format(env_name))

callbacks_p2 = [ModelIntervalCheckpoint(checkpoint_filename_p2, interval=100000)]
callbacks_p2 += [FileLogger(log_filename_p2, interval=1000)]

history_p2 = dqn_p2.fit(env, callbacks=callbacks_p2, nb_steps=NB_STEPS_TRAIN,
                         log_interval=10000, visualize=False)

dqn_p2.save_weights(weights_filename_p2, overwrite=True)
print("Pesos finales de la Propuesta 2 guardados en Drive:", weights_filename_p2)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P2))

# %% [markdown]
# ###### Propuesta 3 — BoltzmannQPolicy

# %%
# ----------------------------------------------------------------------
# PROPUESTA 3: BoltzmannQPolicy
# ----------------------------------------------------------------------
model_p3 = build_model(nb_actions, input_shape)
memory_p3 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p3 = BoltzmannQPolicy(tau=1.)

dqn_p3 = build_dqn_agent(
    model=model_p3, nb_actions=nb_actions, memory=memory_p3,
    processor=AtariProcessor(), policy=policy_p3,
    nb_steps_warmup=10000, target_model_update=10000
)

weights_filename_p3 = os.path.join(WEIGHTS_DIR_P3, 'dqn_{}_p3_boltzmann_weights.h5f'.format(env_name))
checkpoint_filename_p3 = os.path.join(WEIGHTS_DIR_P3, 'dqn_' + env_name + '_p3_weights_{step}.h5f')
log_filename_p3 = os.path.join(WEIGHTS_DIR_P3, 'dqn_{}_p3_log.json'.format(env_name))

callbacks_p3 = [ModelIntervalCheckpoint(checkpoint_filename_p3, interval=100000)]
callbacks_p3 += [FileLogger(log_filename_p3, interval=1000)]

history_p3 = dqn_p3.fit(env, callbacks=callbacks_p3, nb_steps=NB_STEPS_TRAIN,
                         log_interval=10000, visualize=False)

dqn_p3.save_weights(weights_filename_p3, overwrite=True)
print("Pesos finales de la Propuesta 3 guardados en Drive:", weights_filename_p3)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P3))

# %%
# Testing part to calculate the mean reward
#
# NOTA: el objetivo del grupo es superar el primer día de carrera de Enduro
# (pasar el número de coches requerido) durante 100 episodios consecutivos
# en modo test. Cargamos los pesos del mejor modelo entre las 3 propuestas
# y evaluamos sobre 100 episodios para comprobar el criterio de éxito.

# --- Seleccionar aquí la mejor propuesta tras comparar resultados ---
BEST_WEIGHTS = weights_filename_p2  # ajustar según qué propuesta gane

best_model = build_model(nb_actions, input_shape)
dqn_test = build_dqn_agent(
    model=best_model, nb_actions=nb_actions,
    memory=SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH),
    processor=AtariProcessor(), policy=EpsGreedyQPolicy(eps=0.05),
    nb_steps_warmup=10000, target_model_update=10000
)

dqn_test.load_weights(BEST_WEIGHTS)
test_history = dqn_test.test(env, nb_episodes=100, visualize=False)

mean_reward = np.mean(test_history.history['episode_reward'])
std_reward = np.std(test_history.history['episode_reward'])
print(f"Recompensa media en 100 episodios de test: {mean_reward:.2f} (+/- {std_reward:.2f})")

# %% [markdown]
# ##### Empaquetar la entrega (notebook + pesos del mejor modelo)

# %%
# El enunciado pide entregar el notebook junto con los pesos del MEJOR
# modelo en un .zip. Generamos ese .zip directamente dentro de Drive,
# para que solo tengas que descargarlo desde drive.google.com a tu PC
# (C:\Proyectos\VIU\VIU_Apr_por_Refuerzo_Grupo_17_2025_2026 o donde
# prefieras) cuando termine el entrenamiento.
#
# Nota: BEST_WEIGHTS y la carpeta correspondiente (WEIGHTS_DIR_P1/P2/P3)
# ya están definidos más arriba, según qué propuesta resultó ganadora.

import shutil
import glob

# Carpeta de la propuesta ganadora (deducida a partir de BEST_WEIGHTS)
if BEST_WEIGHTS == weights_filename_p1:
    best_weights_dir = WEIGHTS_DIR_P1
elif BEST_WEIGHTS == weights_filename_p2:
    best_weights_dir = WEIGHTS_DIR_P2
else:
    best_weights_dir = WEIGHTS_DIR_P3

ENTREGA_DIR = os.path.join(RESULTS_DIR, 'entrega_final')
os.makedirs(ENTREGA_DIR, exist_ok=True)

# Copiamos el notebook actual y los pesos del mejor modelo (.index +
# .data-*) a la carpeta de entrega.
notebook_candidates = glob.glob(os.path.join(WORK_DIR, '*.ipynb'))
for nb_path in notebook_candidates:
    shutil.copy(nb_path, ENTREGA_DIR)

for f in glob.glob(BEST_WEIGHTS + '*'):
    shutil.copy(f, ENTREGA_DIR)

# Creamos el .zip final dentro de Drive
zip_path_base = os.path.join(RESULTS_DIR, 'entrega_final')
zip_path = shutil.make_archive(zip_path_base, 'zip', ENTREGA_DIR)

print("Entrega empaquetada en Drive:")
print(" ", zip_path)
print("\nContenido incluido:")
for f in os.listdir(ENTREGA_DIR):
    print("  -", f)
print("\nDescárgalo desde drive.google.com (o sincronízalo con Google Drive "
      "for Desktop) a tu PC, por ejemplo a:")
print("  C:\\Proyectos\\VIU\\VIU_Apr_por_Refuerzo_Grupo_17_2025_2026")

# %% [markdown]
# ##### Comparación gráfica de las 3 propuestas

# %%
# ----------------------------------------------------------------------
# PARTE 3: Carga de logs de entrenamiento para comparar las 3 propuestas
# ----------------------------------------------------------------------
import json
import matplotlib.pyplot as plt


def load_log(filename):
    with open(filename, 'r') as f:
        data = json.load(f)
    return data


log_p1 = load_log(log_filename_p1)
log_p2 = load_log(log_filename_p2)
log_p3 = load_log(log_filename_p3)

logs = {
    'Propuesta 1 (EpsGreedy fijo)': log_p1,
    'Propuesta 2 (Annealed EpsGreedy)': log_p2,
    'Propuesta 3 (Boltzmann)': log_p3,
}

# %%
# Gráfica 1: evolución de la recompensa media por episodio durante el entrenamiento
plt.figure(figsize=(10, 6))
for label, log in logs.items():
    plt.plot(log['nb_steps'], log['episode_reward'], label=label, alpha=0.7)
plt.xlabel('Steps de entrenamiento')
plt.ylabel('Reward por episodio')
plt.title('Evolución del reward durante el entrenamiento (Enduro)')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Gráfica 2: media móvil del reward para suavizar la varianza episodio a episodio
import pandas as pd

plt.figure(figsize=(10, 6))
WINDOW = 50
for label, log in logs.items():
    rewards = pd.Series(log['episode_reward'])
    rolling = rewards.rolling(WINDOW, min_periods=1).mean()
    plt.plot(log['nb_steps'], rolling, label=label)
plt.xlabel('Steps de entrenamiento')
plt.ylabel(f'Reward medio (media móvil, ventana={WINDOW})')
plt.title('Comparación de velocidad de aprendizaje entre propuestas')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Gráfica 3: duración media de los episodios (nb_episode_steps) como proxy de
# cuánto tiempo sobrevive / avanza el coche antes de terminar el episodio
plt.figure(figsize=(10, 6))
for label, log in logs.items():
    plt.plot(log['nb_steps'], log['nb_episode_steps'], label=label, alpha=0.7)
plt.xlabel('Steps de entrenamiento')
plt.ylabel('Steps por episodio')
plt.title('Duración de los episodios durante el entrenamiento')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Gráfica 4 (extra): comparación final de medias de test entre las 3 propuestas
# Útil para justificar de forma visual cuál propuesta cumple mejor el
# objetivo (superar el primer día de Enduro en modo test).
final_means = {
    'Propuesta 1\n(EpsGreedy fijo)': np.mean(log_p1['episode_reward'][-50:]),
    'Propuesta 2\n(Annealed)': np.mean(log_p2['episode_reward'][-50:]),
    'Propuesta 3\n(Boltzmann)': np.mean(log_p3['episode_reward'][-50:]),
}

plt.figure(figsize=(8, 6))
plt.bar(final_means.keys(), final_means.values(),
        color=['#4C72B0', '#55A868', '#C44E52'])
plt.ylabel('Reward medio (últimos 50 episodios de entrenamiento)')
plt.title('Comparación final entre las 3 propuestas')
plt.grid(alpha=0.3, axis='y')
plt.show()

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %%
"""
### 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

(Plantilla a completar con los resultados reales una vez entrenadas las 3
propuestas; sustituir los X.XX por los valores obtenidos)

**Resumen de hiperparámetros comparados**

| Propuesta | Política | nb_steps_warmup | target_model_update | Annealing |
|---|---|---|---|---|
| 1 | EpsGreedy fijo (eps=0.2) | 10 000 | 10 000 | No |
| 2 | LinearAnnealed EpsGreedy | 10 000 | 10 000 | 1.0 → 0.1 en 300k steps |
| 3 | Boltzmann (tau=1.0) | 10 000 | 10 000 | No (exploración implícita) |

**Resultados de test (100 episodios, criterio: superar el primer día de
Enduro de forma consecutiva)**

- Propuesta 1: reward medio = X.XX, episodios que superan el día 1 = XX/100
- Propuesta 2: reward medio = X.XX, episodios que superan el día 1 = XX/100
- Propuesta 3: reward medio = X.XX, episodios que superan el día 1 = XX/100

**Discusión**

- ¿Qué propuesta aprendió más rápido en las primeras fases (gráfica 2)? ¿Es
  coherente con la hipótesis de que un annealing más agresivo ayuda a
  explotar antes una señal de reward tan dispersa como la de Enduro?
- ¿La política Boltzmann generó políticas con menos varianza entre episodios
  (gráfica 1) que el EpsGreedy fijo? ¿Por qué cabría esperar eso dado que la
  exploración depende de los propios valores Q en lugar de un parámetro fijo?
- ¿Alguna propuesta no llegó a despegar (reward estancado en 0 durante
  muchos steps)? Relacionar con el diagnóstico inicial sobre lo disperso del
  reward y la necesidad de "descubrir" la acción de acelerar.
- Relación entre duración de episodio (gráfica 3) y reward: en Enduro, vivir
  más tiempo no garantiza más reward si el coche no acelera; comentar si se
  observa este patrón en los resultados (episodios largos con reward bajo
  estarían indicando elusión del choque sin progreso real).
- Concluir cuál de las 3 propuestas se considera la mejor solución final y
  por qué, indicando si se alcanzó o no el objetivo mínimo del grupo.
"""

# %% [markdown]
# ---
