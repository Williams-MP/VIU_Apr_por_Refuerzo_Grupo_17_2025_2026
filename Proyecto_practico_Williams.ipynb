# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 4 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1:
# *   Alumno 2:
# *   Alumno 3:
# *   Alumno 4:

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos. Alternativamente puedes utilizar WSL2: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
import os

# Montar Google Drive y cambiar el directorio de trabajo a la carpeta de checkpoints
if IN_COLAB:
    print("Estamos en Colab (IN_COLAB=True); se montará Google Drive y se cambiará el directorio de trabajo a la carpeta de checkpoints.")
    drive.mount(mount)
    os.makedirs(drive_root, exist_ok=True)
    print("\nColab: Cambiando directorio a", drive_root)
    os.chdir(drive_root)
else:
    print("No estamos en Colab (IN_COLAB=False); se usará el directorio actual del kernel.")

# Capturo el directorio de trabajo actual y muestro su contenido para verificar que es correcto
WORK_DIR = os.getcwd()

# Carpeta de trabajo actual y su contenido
print("\nDirectorio de trabajo actual:", WORK_DIR)
print("Archivos en el directorio:")

# Listar los archivos y carpetas en el directorio de trabajo actual
print(os.listdir(WORK_DIR))

# Crear carpetas de checkpoints para cada práctica
RESULTS_DIR = WORK_DIR

# Crear subcarpetas para cada práctica
WEIGHTS_DIR_P1 = os.path.join(RESULTS_DIR, 'p1_eps_fijo')
WEIGHTS_DIR_P2 = os.path.join(RESULTS_DIR, 'p2_annealed')
WEIGHTS_DIR_P3 = os.path.join(RESULTS_DIR, 'p3_boltzmann')
WEIGHTS_DIR_P4 = os.path.join(RESULTS_DIR, 'p4_double_dqn')
WEIGHTS_DIR_P5 = os.path.join(RESULTS_DIR, 'p5_dueling_dqn')
WEIGHTS_DIR_P6 = os.path.join(RESULTS_DIR, 'p6_double_dueling')
WEIGHTS_DIR_P7 = os.path.join(RESULTS_DIR, 'p7_double_dqn_annealed')
WEIGHTS_DIR_P8 = os.path.join(RESULTS_DIR, 'p8_dueling_dqn_annealed')

# Crear las carpetas si no existen
for d in [RESULTS_DIR, WEIGHTS_DIR_P1, WEIGHTS_DIR_P2, WEIGHTS_DIR_P3,
          WEIGHTS_DIR_P4, WEIGHTS_DIR_P5, WEIGHTS_DIR_P6, WEIGHTS_DIR_P7, WEIGHTS_DIR_P8]:
    os.makedirs(d, exist_ok=True)

# Mostrar las carpetas de checkpoints preparadas
print("\nCarpetas de checkpoints preparadas (en Drive):")
print(" -", WEIGHTS_DIR_P1)
print(" -", WEIGHTS_DIR_P2)
print(" -", WEIGHTS_DIR_P3)
print(" -", WEIGHTS_DIR_P4)
print(" -", WEIGHTS_DIR_P5)
print(" -", WEIGHTS_DIR_P6)
print(" -", WEIGHTS_DIR_P7)
print(" -", WEIGHTS_DIR_P8)

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install tensorflow
  # %pip install tf-keras
  # %pip install tensorflow==2.18.0
  # %pip install tf-keras==2.18.0
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install --upgrade ml_dtypes
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será el indicado en el listado correspondien de cada grupo y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de los puntos indicados en el listado por grupos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN y probar al menos 3 propuestas diferentes de mejora.
# 3.   Justificar la respuesta en relación a los resultados obtenidos e incluir al menos 3 gráficas relevantes comparando las 3 propuestas.
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
#Comprobamos que se carga la versión esperada de TF y detecta la GPU
import os

# Forzar el uso de la versión legacy de Keras para compatibilidad con keras-rl2
os.environ['TF_USE_LEGACY_KERAS']="1"

# Importar TensorFlow y Keras
import tensorflow.keras as tf
import tensorflow as tf1

# Comprobar la versión de TensorFlow y Keras
from keras import __version__
tf.__version__ = __version__

# Comprobar la versión de TensorFlow y la disponibilidad de GPU
print(tf1.__version__)
print(tf1.config.list_physical_devices('GPU'))
print(tf1.config.list_logical_devices('GPU'))

# %%
# Garantiza que las divisiones entre enteros devuelvan flotantes
from __future__ import division

# Importamos PIL para el procesamiento de imágenes, numpy para operaciones numéricas y gym para entornos de aprendizaje por refuerzo
from PIL import Image
import numpy as np
import gym

# Importamos las clases necesarias de Keras y Keras-RL2 para construir y entrenar el agente DQN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute

# Importamos Adam desde la versión legacy de Keras si estamos en Colab, de lo contrario desde la versión estándar
if IN_COLAB:
  from tensorflow.keras.optimizers.legacy import Adam
else:
  from tensorflow.keras.optimizers import Adam

# Importamos Keras backend para operaciones de bajo nivel con tensores
import tensorflow.keras.backend as K

# Importamos los componentes necesarios de Keras-RL2 para construir y entrenar el agente DQN
# Agente encargado del algortimo DQN (Deep Q-Network)
from rl.agents.dqn import DQNAgent 
# Estrategias de exploración y explotación para el agente DQN
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
# Memoria secuencial para almacenar experiencias del agente
from rl.memory import SequentialMemory
# Clases para procesar las observaciones y recompensas del entorno
from rl.core import Processor
# Clases para registrar el progreso del entrenamiento y guardar los modelos periódicamente
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %%
# Este parche soluciona un fallo en keras-rl2 donde el contador de pasos usa np.int16 y
# sufre un overflow al superar los 32,767 pasos, volviéndose negativo y arruinando 
# el entrenamiento (rompe la exploración y el guardado). 
# La solución es forzar dinámicamente el uso de np.int64 en tiempo de ejecución para 
# soportar entrenamientos largos sin modificar el código fuente de la librería.
import rl.core as rl_core
rl_core.np.int16 = np.int64

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'Enduro-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

print("Entorno:", env_name)
print("Número de acciones disponibles:", nb_actions)
print("Significado de las acciones:", env.unwrapped.get_action_meanings())
print("Formato de las observaciones:", env.observation_space)

# %%
class AtariProcessor(Processor):

    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return float(np.clip(reward, -1., 1.))

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
# 1. Implementación de la red neuronal
#
# Usamos la misma arquitectura convolucional propuesta por Mnih et al. (2015)
# para Atari: 3 capas convolucionales + 1 capa densa oculta + capa de salida
# lineal con un valor Q por acción. Es la misma red que en el ejemplo de
# Breakout del notebook de la sesión, adaptada al número de acciones de Enduro.

input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE


def build_model(nb_actions, input_shape):
    model = Sequential()
    if K.image_data_format() == 'channels_last':
        # (width, height, channels)
        model.add(Permute((2, 3, 1), input_shape=input_shape))
    elif K.image_data_format() == 'channels_first':
        # (channels, width, height)
        model.add(Permute((1, 2, 3), input_shape=input_shape))
    else:
        raise RuntimeError('Unknown image_dim_ordering.')

    model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(nb_actions))
    model.add(Activation('linear'))
    return model


model = build_model(nb_actions, input_shape)
print(model.summary())

# %% [markdown]
# ##### Implemenación de la red neuronal para Dueling DQN

# %%
def build_model_dueling_ready(nb_actions, input_shape):

    model = Sequential()
    if K.image_data_format() == 'channels_last':
        model.add(Permute((2, 3, 1), input_shape=input_shape))
    elif K.image_data_format() == 'channels_first':
        model.add(Permute((1, 2, 3), input_shape=input_shape))
    else:
        raise RuntimeError('Unknown image_dim_ordering.')

    model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(nb_actions, activation='linear'))
    return model

# %%
# Para entrenar el agente DQN, definimos el número de pasos de entrenamiento. 
# Este valor puede ajustarse según el tiempo disponible y la frecuencia con la que se deseen guardar los checkpoints del modelo durante el entrenamiento.
NB_STEPS_TRAIN = 1200000

# %%
# Para evaluar el agente DQN, definimos el número de episodios de evaluación.
NB_EPISODES = 10

# %%
# Función para cargar los pesos del último checkpoint disponible para realizar test

def load_weights_for_test(agent, proposal_id, weights_dir):
    """Carga el último checkpoint disponible para poder hacer test."""
    # Buscamos el último checkpoint disponible en la carpeta de pesos correspondiente a la práctica
    ckpt, step = find_latest_checkpoint(weights_dir, f'dqn_Enduro-v0_{proposal_id}')

    # Si se encuentra un archivo de pesos válido en el directorio
    if ckpt is not None:
        # Cargamos los pesos del checkpoint en el agente DQN
        agent.load_weights(ckpt)

        # Imprimimos un mensaje indicando que los pesos han sido cargados
        print(f"[{proposal_id}] Pesos cargados para test desde: {ckpt}  (step {step})")
    else:
        # Si no se encuentra ningún checkpoint, mostramos un mensaje de advertencia
        print(f"[{proposal_id}] Sin checkpoints. Entrena primero.")

# %%
# Función para evaluar una propuesta cargando automáticamente su último checkpoint

def test_proposal(proposal_id, agents_registry, nb_episodes=NB_EPISODES):
    """
    Evaluamos una propuesta cargando automáticamente su último checkpoint.
    agents_registry: dict con la info de cada propuesta (dir, prefix, agente).
    """

    # Validamos si el identificador de la propuesta existe en nuestro diccionario de registro
    if proposal_id not in agents_registry:
        print(f"'{proposal_id}' no está en el registro. Opciones: {list(agents_registry.keys())}")
        return
    
    # Extraemos la información del agente correspondiente a la propuesta
    info = agents_registry[proposal_id]

    # Comprobamos si el agente está en memoria; si no lo está, indicamos que primero debe construirse
    if info['agent'] is None:
        print(f"[{proposal_id}] El agente no está en memoria todavía. Ejecuta primero su celda de construcción.")
        return

    # Buscamos el último checkpoint disponible en la carpeta de pesos correspondiente a la propuesta
    weights_filename, last_step = find_latest_checkpoint(info['dir'], info['prefix'])

    # Si no se encuentra ningún checkpoint, mostramos un mensaje de advertencia y salimos de la función
    if weights_filename is None:
        print(f"[{proposal_id}] Sin checkpoints en {info['dir']}. Entrena primero.")
        return

    # Cargamos los pesos entrenados en el agente antes de iniciar la evaluación
    print(f"[{proposal_id}] Cargando pesos desde: {weights_filename}  (step {last_step})")

    # Cargamos los pesos del último checkpoint en el agente y realizamos la evaluación
    info['agent'].load_weights(weights_filename)

    # Ejecutamos la evaluación del agente en el entorno durante un número especificado de episodios, sin visualización
    test_history = info['agent'].test(env, nb_episodes=nb_episodes, visualize=False)

    # Extraemos las recompensas obtenidas durante los episodios de prueba y calculamos la media y desviación estándar
    mean_reward = np.mean(test_history.history['episode_reward'])
    std_reward  = np.std(test_history.history['episode_reward'])

    # Mostramos los resultados finales por pantalla con formato de dos decimales.
    print(f"[{proposal_id}] Recompensa media en {nb_episodes} episodios: {mean_reward:.2f} (+/- {std_reward:.2f})")
    return test_history

# %%
# Definición del registro global de agentes
# Definimos un diccionario global estructurado como un 'registro de agentes'.
# Centraliza la configuración de todas las propuestas (p1 a p8) para poder iterar,
# entrenar, guardar o testear cualquier modelo dinámicamente usando funciones genéricas.

AGENTS_REGISTRY = {
    'p1': {'dir': WEIGHTS_DIR_P1, 'prefix': 'dqn_Enduro-v0_p1', 'agent': None},
    'p2': {'dir': WEIGHTS_DIR_P2, 'prefix': 'dqn_Enduro-v0_p2', 'agent': None},
    'p3': {'dir': WEIGHTS_DIR_P3, 'prefix': 'dqn_Enduro-v0_p3', 'agent': None},
    'p4': {'dir': WEIGHTS_DIR_P4, 'prefix': 'dqn_Enduro-v0_p4', 'agent': None},
    'p5': {'dir': WEIGHTS_DIR_P5, 'prefix': 'dqn_Enduro-v0_p5', 'agent': None},
    'p6': {'dir': WEIGHTS_DIR_P6, 'prefix': 'dqn_Enduro-v0_p6', 'agent': None},
    'p7': {'dir': WEIGHTS_DIR_P7, 'prefix': 'dqn_Enduro-v0_p7', 'agent': None},
    'p8': {'dir': WEIGHTS_DIR_P8, 'prefix': 'dqn_Enduro-v0_p8', 'agent': None},
}

# %% [markdown]
# 2. Implementación de la solución DQN

# %% [markdown]
# ##### Diagnóstico y diseño de las 3 propuestas de mejora

# %%
# Heredamos de ModelIntervalCheckpoint para solucionar un problema de keras-rl2: su contador
# de guardado siempre empieza en 0. Al reanudar un entrenamiento de 10^6 pasos (por ejemplo, 
# tras una desconexión en el paso 800,000), el callback original sobreescribiría los primeros 
# pesos creados al inicio (100k, 200k...), destruyendo el historial.


class ResumableModelIntervalCheckpoint(ModelIntervalCheckpoint):

    def __init__(self, filepath, interval, step_offset=0, verbose=0): 
        # Llamamos al constructor de la clase base para inicializar los atributos heredados
        super().__init__(filepath, interval, verbose=verbose)

        # Guardamos el offset de pasos para poder reanudar el guardado desde un paso específico
        self.step_offset = step_offset

    def on_step_end(self, step, logs={}):
        # Incrementamos el contador de pasos totales y verificamos si es momento de guardar el modelo
        self.total_steps += 1

        # Si el número total de pasos no es múltiplo del intervalo, no hacemos nada y salimos
        if self.total_steps % self.interval != 0:
            return
        
        # Calculamos el paso absoluto sumando el offset al total de pasos y formateamos la ruta del archivo de pesos
        absolute_step = self.step_offset + self.total_steps
        
        # Formateamos la ruta del archivo de pesos usando el paso absoluto y los registros proporcionados
        filepath = self.filepath.format(step=absolute_step, **logs)
        
        # Si se ha configurado verbose, imprimimos un mensaje indicando que se está guardando el modelo
        if self.verbose > 0:
            print(f'Step {absolute_step}: guardando modelo en {filepath}')
        
        # Guardamos los pesos del modelo en la ruta especificada, sobrescribiendo cualquier archivo existente
        self.model.save_weights(filepath, overwrite=True)

# Función para encontrar el último checkpoint disponible en un directorio de pesos
def find_latest_checkpoint(weights_dir, prefix):
    """
    Busca en weights_dir el checkpoint con el step más alto que siga el
    patrón '{prefix}_weights_{step}.h5f.index', y devuelve una tupla
    (ruta_sin_extension, step) o (None, 0) si no hay ninguno.
    Útil para retomar automáticamente "desde el último punto guardado".
    """
    # Importamos los módulos necesarios para trabajar con expresiones regulares y búsqueda de archivos
    import re
    import glob

    # Construimos el patrón de búsqueda para los archivos de pesos en el directorio especificado
    pattern = os.path.join(weights_dir, f'{prefix}_weights_*.h5f.index')

    # Buscamos todos los archivos que coincidan con el patrón y almacenamos sus rutas en la lista candidates
    candidates = glob.glob(pattern)

    # Inicializamos la variable best_step con un valor negativo para asegurarnos de que cualquier step encontrado será mayor
    best_step = -1

    # Iteramos sobre los archivos encontrados para identificar el checkpoint con el step más alto
    best_path = None

    # Iteramos sobre los archivos encontrados para identificar el checkpoint con el step más alto
    for c in candidates:
        # Usamos una expresión regular para extraer el número de paso del nombre del archivo
        m = re.search(r'_weights_(\d+)\.h5f\.index$', c)

        # Si encontramos un número de paso válido, lo convertimos a entero y comparamos con el mejor paso encontrado hasta ahora
        if m:

            # Extraemos el número de paso del grupo capturado por la expresión regular y lo convertimos a entero
            step = int(m.group(1))

            # Si el paso actual es mayor que el mejor paso encontrado hasta ahora, actualizamos best_step y best_path
            if step > best_step:

                # Actualizamos best_step y best_path con el paso y la ruta del archivo actual
                best_step = step

                # Guardamos la ruta del archivo sin la extensión '.index' para poder cargar los pesos más tarde
                best_path = c[:-len('.index')]

    # Si no se encontró ningún checkpoint válido, devolvemos None y 0
    if best_path is None:
        return None, 0
    return best_path, best_step

# %% [markdown]
# #### **Propuesta 5 — Dueling DQN**

# %% [markdown]
# ##### P5 Policy

# %% [markdown]
# Historial de cambios:
#
# Entrenamiento:
# - Steps de 0 a 1,8M: eps=0,2
# - Steps de 1,8M a 2,3M: eps=
#
# Testeo:
# - eps=

# %%
# Configuración de la Propuesta 5: Dueling DQN
RESUME_FROM_P5 = None
STEP_OFFSET_P5 = 0

# Comentar siguiente línea si no se desea reanudar desde un checkpoint
RESUME_FROM_P5, STEP_OFFSET_P5 = find_latest_checkpoint(WEIGHTS_DIR_P5, 'dqn_Enduro-v0_p5')

# Construimos el modelo, la memoria y la política
model_p5 = build_model_dueling_ready(nb_actions, input_shape)
memory_p5 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p5 = EpsGreedyQPolicy(eps=0.2)

dqn_p5 = build_dqn_agent(
    model=model_p5, nb_actions=nb_actions, memory=memory_p5,
    processor=AtariProcessor(), policy=policy_p5,
    nb_steps_warmup=50000, target_model_update=10000,
    enable_double_dqn=False, enable_dueling_network=True, dueling_type='avg'
)

# Cargamos los pesos del último checkpoint disponible antes de realizar la evaluación
load_weights_for_test(dqn_p5, 'p5', WEIGHTS_DIR_P5)

# Registro del agente DQN en el diccionario de agentes para evaluación posterior. 
AGENTS_REGISTRY['p5']['agent'] = dqn_p5   # ← se registra aquí

# %% [markdown]
# ##### P5 Entrenamiento

# %%
# Usar TRUE para entrenar, o FALSE para saltar el entrenamiento 
RUN_TRAINING_P5 = False          # <── GUARDIA PRINCIPAL

if RUN_TRAINING_P5:

    if RESUME_FROM_P5 is not None:
        print(f"Reanudando Propuesta 5 desde el checkpoint: {RESUME_FROM_P5}")
        dqn_p5.load_weights(RESUME_FROM_P5)
        NB_STEPS_REMAINING_P5 = max(0, NB_STEPS_TRAIN - STEP_OFFSET_P5)
    else:
        NB_STEPS_REMAINING_P5 = NB_STEPS_TRAIN

    weights_filename_p5 = os.path.join(WEIGHTS_DIR_P5, 'dqn_{}_p5_dueling_dqn_weights.h5f'.format(env_name))
    checkpoint_filename_p5 = os.path.join(WEIGHTS_DIR_P5, 'dqn_' + env_name + '_p5_weights_{step}.h5f')
    log_filename_p5 = os.path.join(WEIGHTS_DIR_P5, 'dqn_{}_p5_log.json'.format(env_name))

    callbacks_p5 = [ResumableModelIntervalCheckpoint(checkpoint_filename_p5, interval=100000,
                                                    step_offset=STEP_OFFSET_P5)]
    callbacks_p5 += [FileLogger(log_filename_p5, interval=1000)]

    history_p5 = dqn_p5.fit(env, callbacks=callbacks_p5, nb_steps=NB_STEPS_REMAINING_P5,
                            log_interval=10000, visualize=False)

    dqn_p5.save_weights(weights_filename_p5, overwrite=True)
    print("Pesos finales de la Propuesta 5 guardados en Drive:", weights_filename_p5)
    print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P5))

else:
    print("[P5] Entrenamiento omitido (RUN_TRAINING_P5=False).")
# Out:
# Reanudando Propuesta 5 desde el checkpoint: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p5_dueling_dqn/dqn_Enduro-v0_p5_weights_1100000.h5f
# Training for 700000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 47s 5ms/step - reward: 0.0207
# 2 episodes - episode_reward: 103.500 [76.000, 131.000] - ale.lives: 0.000
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 46s 5ms/step - reward: 0.0241
# 2 episodes - episode_reward: 105.000 [79.000, 131.000] - ale.lives: 0.000
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 49s 5ms/step - reward: 0.0304
# 2 episodes - episode_reward: 134.500 [120.000, 149.000] - ale.lives: 0.000
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 47s 5ms/step - reward: 0.0354
# 2 episodes - episode_reward: 133.000 [128.000, 138.000] - ale.lives: 0.000
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 48s 5ms/step - reward: 0.0229
# 3 episodes - episode_reward: 127.333 [94.000, 154.000] - ale.lives: 0.000
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0292
# 2 episodes - episode_reward: 137.000 [111.000, 163.000] - loss: 0.089 - mae: 5.390 - mean_q: 6.213 - ale.lives: 0.000
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0245
# 2 episodes - episode_reward: 105.000 [89.000, 121.000] - loss: 0.079 - mae: 5.422 - mean_q: 6.248 - ale.lives: 0.000
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0308
# 3 episodes - episode_reward: 120.667 [102.000, 134.000] - loss: 0.074 - mae: 5.508 - mean_q: 6.346 - ale.lives: 0.000
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 0.0281
# 2 episodes - episode_reward: 123.500 [121.000, 126.000] - loss: 0.070 - mae: 5.556 - mean_q: 6.408 - ale.lives: 0.000
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 347s 35ms/step - reward: 0.0185
# 2 episodes - episode_reward: 85.000 [60.000, 110.000] - loss: 0.067 - mae: 5.600 - mean_q: 6.455 - ale.lives: 0.000
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 338s 34ms/step - reward: 0.0300
# 2 episodes - episode_reward: 137.500 [121.000, 154.000] - loss: 0.070 - mae: 5.682 - mean_q: 6.554 - ale.lives: 0.000
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 0.0272
# 3 episodes - episode_reward: 115.000 [74.000, 149.000] - loss: 0.073 - mae: 5.662 - mean_q: 6.524 - ale.lives: 0.000
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 0.0262
# 2 episodes - episode_reward: 116.000 [111.000, 121.000] - loss: 0.074 - mae: 5.744 - mean_q: 6.621 - ale.lives: 0.000
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 335s 33ms/step - reward: 0.0309
# 2 episodes - episode_reward: 133.000 [121.000, 145.000] - loss: 0.069 - mae: 5.787 - mean_q: 6.670 - ale.lives: 0.000
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0202
# 2 episodes - episode_reward: 114.000 [104.000, 124.000] - loss: 0.070 - mae: 5.778 - mean_q: 6.656 - ale.lives: 0.000
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 354s 35ms/step - reward: 0.0239
# 3 episodes - episode_reward: 94.667 [81.000, 108.000] - loss: 0.068 - mae: 5.864 - mean_q: 6.754 - ale.lives: 0.000
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 342s 34ms/step - reward: 0.0281
# 2 episodes - episode_reward: 125.000 [68.000, 182.000] - loss: 0.071 - mae: 5.944 - mean_q: 6.845 - ale.lives: 0.000
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 341s 34ms/step - reward: 0.0256
# 2 episodes - episode_reward: 132.000 [126.000, 138.000] - loss: 0.072 - mae: 5.991 - mean_q: 6.894 - ale.lives: 0.000
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 342s 34ms/step - reward: 0.0232
# 2 episodes - episode_reward: 107.500 [103.000, 112.000] - loss: 0.073 - mae: 6.056 - mean_q: 6.970 - ale.lives: 0.000
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 346s 35ms/step - reward: 0.0341
# 3 episodes - episode_reward: 125.333 [74.000, 178.000] - loss: 0.077 - mae: 6.083 - mean_q: 7.008 - ale.lives: 0.000
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 344s 34ms/step - reward: 0.0255
# 2 episodes - episode_reward: 121.500 [117.000, 126.000] - loss: 0.079 - mae: 6.211 - mean_q: 7.153 - ale.lives: 0.000
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 345s 35ms/step - reward: 0.0245
# 2 episodes - episode_reward: 117.500 [102.000, 133.000] - loss: 0.078 - mae: 6.242 - mean_q: 7.187 - ale.lives: 0.000
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 352s 35ms/step - reward: 0.0361
# 2 episodes - episode_reward: 145.500 [142.000, 149.000] - loss: 0.074 - mae: 6.221 - mean_q: 7.162 - ale.lives: 0.000
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 349s 35ms/step - reward: 0.0258
# 3 episodes - episode_reward: 115.667 [85.000, 158.000] - loss: 0.075 - mae: 6.254 - mean_q: 7.191 - ale.lives: 0.000
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 349s 35ms/step - reward: 0.0298
# 2 episodes - episode_reward: 138.500 [129.000, 148.000] - loss: 0.082 - mae: 6.323 - mean_q: 7.272 - ale.lives: 0.000
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 352s 35ms/step - reward: 0.0254
# 2 episodes - episode_reward: 116.500 [115.000, 118.000] - loss: 0.076 - mae: 6.420 - mean_q: 7.380 - ale.lives: 0.000
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 0.0296
# 2 episodes - episode_reward: 121.500 [121.000, 122.000] - loss: 0.080 - mae: 6.498 - mean_q: 7.467 - ale.lives: 0.000
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0273
# 3 episodes - episode_reward: 123.333 [121.000, 125.000] - loss: 0.079 - mae: 6.544 - mean_q: 7.522 - ale.lives: 0.000
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 360s 36ms/step - reward: 0.0256
# 2 episodes - episode_reward: 115.000 [109.000, 121.000] - loss: 0.075 - mae: 6.577 - mean_q: 7.558 - ale.lives: 0.000
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 378s 38ms/step - reward: 0.0330
# 2 episodes - episode_reward: 146.000 [118.000, 174.000] - loss: 0.080 - mae: 6.634 - mean_q: 7.628 - ale.lives: 0.000
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 372s 37ms/step - reward: 0.0272
# 2 episodes - episode_reward: 141.500 [112.000, 171.000] - loss: 0.083 - mae: 6.723 - mean_q: 7.726 - ale.lives: 0.000
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 376s 38ms/step - reward: 0.0335
# 3 episodes - episode_reward: 127.667 [103.000, 146.000] - loss: 0.077 - mae: 6.789 - mean_q: 7.799 - ale.lives: 0.000
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 363s 36ms/step - reward: 0.0234
# 2 episodes - episode_reward: 115.000 [96.000, 134.000] - loss: 0.087 - mae: 6.850 - mean_q: 7.872 - ale.lives: 0.000
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 355s 35ms/step - reward: 0.0311
# 2 episodes - episode_reward: 130.000 [123.000, 137.000] - loss: 0.084 - mae: 6.897 - mean_q: 7.918 - ale.lives: 0.000
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 0.0262
# 2 episodes - episode_reward: 107.500 [95.000, 120.000] - loss: 0.089 - mae: 7.025 - mean_q: 8.063 - ale.lives: 0.000
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 361s 36ms/step - reward: 0.0277
# 3 episodes - episode_reward: 124.667 [111.000, 141.000] - loss: 0.087 - mae: 7.013 - mean_q: 8.053 - ale.lives: 0.000
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 369s 37ms/step - reward: 0.0251
# 2 episodes - episode_reward: 110.000 [105.000, 115.000] - loss: 0.089 - mae: 6.993 - mean_q: 8.029 - ale.lives: 0.000
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 367s 37ms/step - reward: 0.0359
# 2 episodes - episode_reward: 164.000 [138.000, 190.000] - loss: 0.082 - mae: 7.055 - mean_q: 8.094 - ale.lives: 0.000
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 374s 37ms/step - reward: 0.0320
# 2 episodes - episode_reward: 128.500 [124.000, 133.000] - loss: 0.087 - mae: 7.064 - mean_q: 8.114 - ale.lives: 0.000
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 383s 38ms/step - reward: 0.0252
# 3 episodes - episode_reward: 124.000 [113.000, 146.000] - loss: 0.080 - mae: 6.987 - mean_q: 8.016 - ale.lives: 0.000
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 382s 38ms/step - reward: 0.0276
# 2 episodes - episode_reward: 122.500 [111.000, 134.000] - loss: 0.076 - mae: 6.984 - mean_q: 8.011 - ale.lives: 0.000
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 410s 41ms/step - reward: 0.0306
# 2 episodes - episode_reward: 149.500 [119.000, 180.000] - loss: 0.082 - mae: 6.982 - mean_q: 8.010 - ale.lives: 0.000
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 412s 41ms/step - reward: 0.0317
# 2 episodes - episode_reward: 115.000 [108.000, 122.000] - loss: 0.090 - mae: 7.066 - mean_q: 8.109 - ale.lives: 0.000
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 401s 40ms/step - reward: 0.0334
# 3 episodes - episode_reward: 153.333 [144.000, 165.000] - loss: 0.082 - mae: 7.110 - mean_q: 8.155 - ale.lives: 0.000
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 387s 39ms/step - reward: 0.0296
# 2 episodes - episode_reward: 140.000 [113.000, 167.000] - loss: 0.080 - mae: 7.162 - mean_q: 8.214 - ale.lives: 0.000
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 395s 40ms/step - reward: 0.0382
# 2 episodes - episode_reward: 165.000 [152.000, 178.000] - loss: 0.082 - mae: 7.170 - mean_q: 8.226 - ale.lives: 0.000
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 395s 39ms/step - reward: 0.0336
# 2 episodes - episode_reward: 151.500 [135.000, 168.000] - loss: 0.083 - mae: 7.236 - mean_q: 8.302 - ale.lives: 0.000
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 395s 39ms/step - reward: 0.0310
# 3 episodes - episode_reward: 139.000 [131.000, 148.000] - loss: 0.084 - mae: 7.291 - mean_q: 8.364 - ale.lives: 0.000
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 392s 39ms/step - reward: 0.0256
# 2 episodes - episode_reward: 124.500 [106.000, 143.000] - loss: 0.085 - mae: 7.349 - mean_q: 8.422 - ale.lives: 0.000
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 388s 39ms/step - reward: 0.0291
# 2 episodes - episode_reward: 126.500 [115.000, 138.000] - loss: 0.084 - mae: 7.408 - mean_q: 8.488 - ale.lives: 0.000
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 393s 39ms/step - reward: 0.0346
# 2 episodes - episode_reward: 128.000 [113.000, 143.000] - loss: 0.082 - mae: 7.392 - mean_q: 8.469 - ale.lives: 0.000
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 397s 40ms/step - reward: 0.0261
# 3 episodes - episode_reward: 135.667 [120.000, 158.000] - loss: 0.089 - mae: 7.467 - mean_q: 8.549 - ale.lives: 0.000
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 401s 40ms/step - reward: 0.0285
# 2 episodes - episode_reward: 126.500 [123.000, 130.000] - loss: 0.083 - mae: 7.488 - mean_q: 8.572 - ale.lives: 0.000
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 402s 40ms/step - reward: 0.0356
# 2 episodes - episode_reward: 146.500 [146.000, 147.000] - loss: 0.093 - mae: 7.552 - mean_q: 8.650 - ale.lives: 0.000
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 400s 40ms/step - reward: 0.0339
# 2 episodes - episode_reward: 140.500 [138.000, 143.000] - loss: 0.092 - mae: 7.611 - mean_q: 8.724 - ale.lives: 0.000
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 410s 41ms/step - reward: 0.0335
# 3 episodes - episode_reward: 160.333 [137.000, 189.000] - loss: 0.092 - mae: 7.693 - mean_q: 8.816 - ale.lives: 0.000
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 410s 41ms/step - reward: 0.0269
# 2 episodes - episode_reward: 124.000 [112.000, 136.000] - loss: 0.096 - mae: 7.739 - mean_q: 8.863 - ale.lives: 0.000
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 408s 41ms/step - reward: 0.0319
# 2 episodes - episode_reward: 128.000 [114.000, 142.000] - loss: 0.087 - mae: 7.674 - mean_q: 8.783 - ale.lives: 0.000
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 414s 41ms/step - reward: 0.0261
# 2 episodes - episode_reward: 122.500 [112.000, 133.000] - loss: 0.091 - mae: 7.700 - mean_q: 8.813 - ale.lives: 0.000
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 418s 42ms/step - reward: 0.0293
# 3 episodes - episode_reward: 135.333 [117.000, 172.000] - loss: 0.089 - mae: 7.745 - mean_q: 8.872 - ale.lives: 0.000
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 424s 42ms/step - reward: 0.0220
# 2 episodes - episode_reward: 90.500 [79.000, 102.000] - loss: 0.095 - mae: 7.766 - mean_q: 8.897 - ale.lives: 0.000
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 428s 43ms/step - reward: 0.0322
# 2 episodes - episode_reward: 134.500 [124.000, 145.000] - loss: 0.103 - mae: 7.905 - mean_q: 9.054 - ale.lives: 0.000
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 442s 44ms/step - reward: 0.0298
# 2 episodes - episode_reward: 132.500 [129.000, 136.000] - loss: 0.099 - mae: 7.903 - mean_q: 9.051 - ale.lives: 0.000
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 453s 45ms/step - reward: 0.0295
# 3 episodes - episode_reward: 131.333 [115.000, 145.000] - loss: 0.100 - mae: 7.978 - mean_q: 9.133 - ale.lives: 0.000
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 445s 44ms/step - reward: 0.0305
# 2 episodes - episode_reward: 143.500 [126.000, 161.000] - loss: 0.110 - mae: 7.958 - mean_q: 9.114 - ale.lives: 0.000
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 443s 44ms/step - reward: 0.0331
# 2 episodes - episode_reward: 130.500 [129.000, 132.000] - loss: 0.103 - mae: 8.060 - mean_q: 9.228 - ale.lives: 0.000
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 432s 43ms/step - reward: 0.0285
# 2 episodes - episode_reward: 137.000 [124.000, 150.000] - loss: 0.097 - mae: 8.063 - mean_q: 9.229 - ale.lives: 0.000
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 434s 43ms/step - reward: 0.0285
# 3 episodes - episode_reward: 128.667 [120.000, 141.000] - loss: 0.102 - mae: 7.997 - mean_q: 9.154 - ale.lives: 0.000
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 445s 44ms/step - reward: 0.0365
# 1 episodes - episode_reward: 149.000 [149.000, 149.000] - loss: 0.096 - mae: 7.982 - mean_q: 9.140 - ale.lives: 0.000
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 451s 45ms/step - reward: 0.0390
# done, took 24959.509 seconds
# Pesos finales de la Propuesta 5 guardados en Drive: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p5_dueling_dqn/dqn_Enduro-v0_p5_dueling_dqn_weights.h5f
# Contenido de la carpeta: ['dqn_Enduro-v0_p5_weights_100000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_100000.h5f.index', 'dqn_Enduro-v0_p5_weights_200000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_200000.h5f.index', 'dqn_Enduro-v0_p5_weights_300000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_300000.h5f.index', 'dqn_Enduro-v0_p5_weights_400000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_400000.h5f.index', 'dqn_Enduro-v0_p5_weights_500000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_500000.h5f.index', 'dqn_Enduro-v0_p5_weights_600000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_600000.h5f.index', 'dqn_Enduro-v0_p5_weights_700000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_700000.h5f.index', 'dqn_Enduro-v0_p5_weights_800000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_800000.h5f.index', 'dqn_Enduro-v0_p5_weights_900000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_900000.h5f.index', 'dqn_Enduro-v0_p5_weights_1000000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1000000.h5f.index', 'dqn_Enduro-v0_p5_dueling_dqn_weights.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_dueling_dqn_weights.h5f.index', 'dqn_Enduro-v0_p5_log.json', 'dqn_Enduro-v0_p5_weights_1100000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1100000.h5f.index', 'checkpoint', 'dqn_Enduro-v0_p5_weights_1200000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1200000.h5f.index', 'dqn_Enduro-v0_p5_weights_1300000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1300000.h5f.index', 'dqn_Enduro-v0_p5_weights_1400000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1400000.h5f.index', 'dqn_Enduro-v0_p5_weights_1500000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1500000.h5f.index', 'dqn_Enduro-v0_p5_weights_1600000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1600000.h5f.index', 'dqn_Enduro-v0_p5_weights_1700000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1700000.h5f.index', 'dqn_Enduro-v0_p5_weights_1800000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1800000.h5f.index']

# %% [markdown]
# ##### P5 Testeo

# %%
# Seleccionamos la propuesta a evaluar (p1, p2, p3, p4, p5, p6, p7 o p8)
PROPUESTA_A_EVALUAR = 'p5'   # ← único parámetro a tocar

# Evaluamos la propuesta cargando automáticamente su último checkpoint
test_history = test_proposal(PROPUESTA_A_EVALUAR, AGENTS_REGISTRY)
# Out:
# [p5] Cargando pesos desde: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p5_dueling_dqn/dqn_Enduro-v0_p5_weights_1800000.h5f  (step 1800000)
# Testing for 10 episodes ...
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Episode 1: reward: 311.000, steps: 8891
# Episode 2: reward: 163.000, steps: 4449
# Episode 3: reward: 179.000, steps: 4442
# Episode 4: reward: 412.000, steps: 8878
# Episode 5: reward: 184.000, steps: 4470
# Episode 6: reward: 180.000, steps: 4423
# Episode 7: reward: 153.000, steps: 4448
# Episode 8: reward: 199.000, steps: 4452
# Episode 9: reward: 381.000, steps: 8888
# Episode 10: reward: 196.000, steps: 4451
# [p5] Recompensa media en 10 episodios: 235.80 (+/- 90.50)
